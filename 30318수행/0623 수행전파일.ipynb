# %%
import matplotlib.pyplot as plt
a=[10, 20, 30, 40]
b=['kor','eng','mat','info']
plt.plot(a,b)
plt.ylabel('some numbers')
# Out:
# Text(0, 0.5, 'some numbers')

# %%
import matplotlib.pyplot as plt
a=[10, 20, 30, 40]
b=['kor','eng','mat','info']
plt.bar(b,a,color='red')
plt.ylabel('jumsu')
plt.xlabel('subject')
plt.title('chicken')
plt.legend('value')
